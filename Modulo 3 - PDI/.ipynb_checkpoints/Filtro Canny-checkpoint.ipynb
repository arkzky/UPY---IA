# %% [markdown]
# # Filtro Canny

# %%
from skimage import io, feature
from skimage.color import rgb2gray

# %%
imag = io.imread("Stitch.png")
io.imshow(imag)
io.show()

# %%
img = rgb2gray(imag)
io.imshow(img)
io.show()

# %%
canny = feature.canny(img)
io.imshow(canny)
io.show()
