# %% [markdown]
# # Detección de bordes

# %% [markdown]
# ## Sobel

# %%
from skimage import io, filters
from skimage.color import rgb2gray

# %%
imagen = io.imread("Mariposa.jpg")
io.imshow(imagen)
io.show()

# %%
imagGris = rgb2gray(imagen)
io.imshow(imagGris)
io.show()

# %%
sobel = filters.sobel(imagGris)
io.imshow(sobel)
io.show()

# %% [markdown]
# ## Prewit

# %%
prewitt = filters.prewitt(imagGris)
io.imshow(prewitt)
io.show()
